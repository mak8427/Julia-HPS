# %% [markdown]
# # Benchmarking Julia Code
#
# This notebook is largely inspired by [this excellent blog post](https://opensourc.es/blog/matrix-multiplication-performance/) and illustrates how to benchmark Julia code, as well as a few useful tricks for optimizing it. You'll need a couple of packages to get it running on your machine. Simply run the next cell to install them.
#
# **NOTE:** Installing packages can take a couple of minutes

# %%
using Pkg
Pkg.add("BenchmarkTools")
Pkg.add("StatsPlots")
Pkg.add("LoopVectorization")
# Out:
#     Updating registry at `C:\Users\dadoi\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed BenchmarkTools ─ v1.5.0
#     Updating `C:\Users\dadoi\.julia\environments\v1.10\Project.toml`
#   [6e4b80f9] + BenchmarkTools v1.5.0
#     Updating `C:\Users\dadoi\.julia\environments\v1.10\Manifest.toml`
#   [6e4b80f9] + BenchmarkTools v1.5.0
#   [9abbd945] + Profile
# Precompiling project...
#   ✓ CUDA_Runtime_jll
#   ✓ BenchmarkTools
#   2 dependencies successfully precompiled in 9 seconds. 216 already precompiled. 1 skipped during auto due to previous errors.
#    Resolving package versions...
#    Installed OffsetArrays ──────────── v1.14.0
#    Installed Calculus ──────────────── v0.5.1
#    Installed IntelOpenMP_jll ───────── v2024.1.0+0
#    Installed PDMats ────────────────── v0.11.31
#    Installed NearestNeighbors ──────── v0.4.16
#    Installed Distances ─────────────── v0.10.11
#    Installed PtrArrays ─────────────── v1.2.0
#    Installed StatsFuns ─────────────── v1.3.1
#    Installed Rmath_jll ─────────────── v0.4.2+0
#    Installed Ratios ────────────────── v0.4.5
#    Installed StatsPlots ────────────── v0.15.7
#    Installed HypergeometricFunctions ─ v0.3.23
#    Installed MKL_jll ───────────────── v2024.1.0+0
#    Installed oneTBB_jll ────────────── v2021.12.0+0
#    Installed FFTW ──────────────────── v1.8.0
#    Installed Clustering ────────────── v0.15.7
#    Installed KernelDensity ─────────── v0.6.9
#    Installed AliasTables ───────────── v1.1.3
#    Installed ChainRulesCore ────────── v1.24.0
#    Installed FFTW_jll ──────────────── v3.3.10+0
#    Installed MultivariateStats ─────── v0.10.2
#    Installed Interpolations ────────── v0.15.1
#    Installed DualNumbers ───────────── v0.6.8
#    Installed Arpack_jll ────────────── v3.5.1+1
#    Installed Rmath ─────────────────── v0.7.1
#    Installed TableOperations ───────── v1.2.0
#    Installed WoodburyMatrices ──────── v1.0.0
#    Installed Arpack ────────────────── v0.5.4
#    Installed QuadGK ────────────────── v2.9.4
#    Installed AxisAlgorithms ────────── v1.1.0
#    Installed Distributions ─────────── v0.25.109
#     Updating `C:\Users\dadoi\.julia\environments\v1.10\Project.toml`
#   [f3b207a7] + StatsPlots v0.15.7
#     Updating `C:\Users\dadoi\.julia\environments\v1.10\Manifest.toml`
#   [66dad0bd] + AliasTables v1.1.3
#   [7d9fca2a] + Arpack v0.5.4
#   [13072b0f] + AxisAlgorithms v1.1.0
#   [49dc2e85] + Calculus v0.5.1
#   [d360d2e6] + ChainRulesCore v1.24.0
#   [aaaa29a8] + Clustering v0.15.7
#   [b4f34e82] + Distances v0.10.11
#   [31c24e10] + Distributions v0.25.109
#   [fa6b7ba4] + DualNumbers v0.6.8
#   [7a1cc6ca] + FFTW v1.8.0
#   [1a297f60] + FillArrays v1.11.0
#   [34004b35] + HypergeometricFunctions v0.3.23
#   [a98d9a8b] + Interpolations v0.15.1
#   [5ab0869b] + KernelDensity v0.6.9
#   [6f286f6a] + MultivariateStats v0.10.2
#   [b8a86587] + NearestNeighbors v0.4.16
#   [6fe1bfb0] + OffsetArrays v1.14.0
#   [90014a1f] + PDMats v0.11.31
#   [43287f4e] + PtrArrays v1.2.0
#   [1fd47b50] + QuadGK v2.9.4
#   [c84ed2f1] + Ratios v0.4.5
#   [79098fc4] + Rmath v0.7.1
#   [276daf66] + SpecialFunctions v2.4.0
#   [4c63d2b9] + StatsFuns v1.3.1
#   [f3b207a7] + StatsPlots v0.15.7
#   [ab02a1b2] + TableOperations v1.2.0
#   [efce3f68] + WoodburyMatrices v1.0.0
# ⌅ [68821587] + Arpack_jll v3.5.1+1
#   [f5851436] + FFTW_jll v3.3.10+0
#   [1d5cc7b8] + IntelOpenMP_jll v2024.1.0+0
#   [856f044c] + MKL_jll v2024.1.0+0
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
#   [f50d1b31] + Rmath_jll v0.4.2+0
#   [1317d2d5] + oneTBB_jll v2021.12.0+0
#   [1a1011a3] + SharedArrays
#   [4607b0f0] + SuiteSparse
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ PtrArrays
#   ✓ Ratios
#   ✓ Calculus
#   ✓ Rmath_jll
#   ✓ FFTW_jll
#   ✓ IntelOpenMP_jll
#   ✓ Arpack_jll
#   ✓ oneTBB_jll
#   ✓ WoodburyMatrices
#   ✓ PDMats
#   ✓ OffsetArrays
#   ✓ TableOperations
#   ✓ AliasTables
#   ✓ ChainRulesCore
#   ✓ Distances
#   ✓ Ratios → RatiosFixedPointNumbersExt
#   ✓ Arpack
#   ✓ Rmath
#   ✓ AxisAlgorithms
#   ✓ OffsetArrays → OffsetArraysAdaptExt
#   ✓ FillArrays → FillArraysPDMatsExt
#   ✓ QuadGK
#   ✓ AbstractFFTs → AbstractFFTsChainRulesCoreExt
#   ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#   ✓ Distances → DistancesSparseArraysExt
#   ✓ StaticArrays → StaticArraysChainRulesCoreExt
#   ✓ Distances → DistancesChainRulesCoreExt
#   ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#   ✓ Interpolations
#   ✓ NearestNeighbors
#   ✓ MultivariateStats
#   ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#   ✓ Interpolations → InterpolationsUnitfulExt
#   ✓ DualNumbers
#   ✓ Clustering
#   ✓ HypergeometricFunctions
#   ✓ StatsFuns
#   ✓ StatsFuns → StatsFunsChainRulesCoreExt
#   ✓ Distributions
#   ✓ Distributions → DistributionsTestExt
#   ✓ Distributions → DistributionsChainRulesCoreExt
# MKL_jll Waiting for background task / IO / timer.
# [pid 30508] waiting for IO to finish:
#  Handle type        uv_handle_t->data
#  timer              000001e58bd33740->000001e589b8c430
# This means that a package has started a background task or event source that has not finished running. For precompilation to complete successfully, the event source needs to be closed explicitly. See the developer documentation on fixing precompilation hangs for more help.
#   ✓ CUDA → SpecialFunctionsExt
#
# [pid 30508] waiting for IO to finish:
#  Handle type        uv_handle_t->data
#  timer              000001e58bd33740->000001e589b8c430
# This means that a package has started a background task or event source that has not finished running. For precompilation to complete successfully, the event source needs to be closed explicitly. See the developer documentation on fixing precompilation hangs for more help.
#   ✓ CUDA → ChainRulesCoreExt
#   ✓ MKL_jll
#   ✓ FFTW
#   ✓ KernelDensity
#   ✓ StatsPlots
#   47 dependencies successfully precompiled in 70 seconds. 226 already precompiled. 1 skipped during auto due to previous errors.
#   1 dependency had output during precompilation:
# ┌ MKL_jll
# │   Downloading artifact: MKL
# │
# │  [pid 30508] waiting for IO to finish:
# │   Handle type        uv_handle_t->data
# │   timer              000001e58bd33740->000001e589b8c430
# │  This means that a package has started a background task or event source that has not finished running. For precompilation to complete successfully, the event source needs to be closed explicitly. See the developer documentation on fixing precompilation hangs for more help.
# │
# │  [pid 30508] waiting for IO to finish:
# │   Handle type        uv_handle_t->data
# │   timer              000001e58bd33740->000001e589b8c430
# │  This means that a package has started a background task or event source that has not finished running. For precompilation to complete successfully, the event source needs to be closed explicitly. See the developer documentation on fixing precompilation hangs for more help.
# └
#    Resolving package versions...
#    Installed ThreadingUtilities ─────────────── v0.5.2
#    Installed SLEEFPirates ───────────────────── v0.6.42
#    Installed IfElse ─────────────────────────── v0.1.1
#    Installed StaticArrayInterface ───────────── v1.5.0
#    Installed SIMDTypes ──────────────────────── v0.1.0
#    Installed Static ─────────────────────────── v0.8.10
#    Installed CpuId ──────────────────────────── v0.3.1
#    Installed LayoutPointers ─────────────────── v0.1.15
#    Installed ManualMemory ───────────────────── v0.1.8
#    Installed PolyesterWeave ─────────────────── v0.2.1
#    Installed CloseOpenIntervals ─────────────── v0.1.12
#    Installed BitTwiddlingConvenienceFunctions ─ v0.1.5
#    Installed VectorizationBase ──────────────── v0.21.68
#    Installed LoopVectorization ──────────────── v0.12.170
#    Installed CPUSummary ─────────────────────── v0.2.5
#    Installed HostCPUFeatures ────────────────── v0.1.16
#     Updating `C:\Users\dadoi\.julia\environments\v1.10\Project.toml`
#   [bdcacae8] + LoopVectorization v0.12.170
#     Updating `C:\Users\dadoi\.julia\environments\v1.10\Manifest.toml`
#   [4fba245c] + ArrayInterface v7.10.0
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.5
#   [2a0fbf3d] + CPUSummary v0.2.5
#   [fb6a15b2] + CloseOpenIntervals v0.1.12
#   [adafc99b] + CpuId v0.3.1
#   [3e5b6fbb] + HostCPUFeatures v0.1.16
#   [615f187c] + IfElse v0.1.1
#   [10f19ff3] + LayoutPointers v0.1.15
#   [bdcacae8] + LoopVectorization v0.12.170
#   [d125e4d3] + ManualMemory v0.1.8
#   [1d0040c9] + PolyesterWeave v0.2.1
#   [94e857df] + SIMDTypes v0.1.0
#   [476501e8] + SLEEFPirates v0.6.42
#   [aedffcd0] + Static v0.8.10
#   [0d7ed370] + StaticArrayInterface v1.5.0
#   [8290d209] + ThreadingUtilities v0.5.2
#   [3d5dd08c] + VectorizationBase v0.21.68
# Precompiling project...
#   ✓ IfElse
#   ✓ SIMDTypes
#   ✓ ManualMemory
#   ✓ CpuId
#   ✓ ArrayInterface → ArrayInterfaceGPUArraysCoreExt
#   ✓ Static
#   ✓ BitTwiddlingConvenienceFunctions
#   ✓ ThreadingUtilities
#   ✓ HostCPUFeatures
#   ✓ CPUSummary
#   ✓ PolyesterWeave
#   ✓ ArrayInterface → ArrayInterfaceCUDAExt
#   ✓ StaticArrayInterface
#   ✓ StaticArrayInterface → StaticArrayInterfaceStaticArraysExt
#   ✓ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#   ✓ CloseOpenIntervals
#   ✓ LayoutPointers
#   ✓ VectorizationBase
#   ✓ SLEEFPirates
#   ✓ LoopVectorization
#   ✓ LoopVectorization → SpecialFunctionsExt
#   21 dependencies successfully precompiled in 32 seconds. 275 already precompiled. 1 skipped during auto due to previous errors.

# %% [markdown]
# In this notebook, we'll examine the performance of the humble matrix multiplication. We'll start with a naive implementation, and gradually optimize it.

# %%
# This function performs the update C = C + A*B without allocating memory
function simple_mul!(C,A,B)
    m,n = size(C)
    l = size(A,2)
    for i in 1:m, j in 1:n, k in 1:l
        C[i,j] += A[i,k]*B[k,j]
    end
end
# Out:
# simple_mul! (generic function with 1 method)

# %%
n = 256
A = rand(n,n);
B = rand(n,n);
C = rand(n,n);

# %% [markdown]
# The Julia standard provides a macro called `@time` to evaluate the running time of an expression (e.g. a function call)

# %%
@time simple_mul!(C,A,B)
# Out:
#   0.026365 seconds (10.20 k allocations: 703.422 KiB, 63.12% compilation time)

# %% [markdown]
# Note that the above mentions allocations and time spent for compiling the function, so it is not representative of the real performance. If we run the macro again, we see that it takes about 20 ms to compute the product of two 256 times 256 matrices.

# %%
@time simple_mul!(C,A,B)
# Out:
#   0.009345 seconds

# %% [markdown]
# Using `@time` is fine to get a quick idea of performance, but it only measures the time for one function call. For proper benchmarking, we'll need to bust out the power tools.
#
# Luckily for us, the `BenchmarkTools` package provides just that. It exports several macros, including `@btime` and `@benchmark` which run the expression multiple times to get a better estimate of its performance.

# %%
using BenchmarkTools

# %%
b_simple = @benchmark simple_mul!(C,A,B)
# Out:
# BenchmarkTools.Trial: 505 samples with 1 evaluation.
#  Range (min … max):  9.054 ms …  12.961 ms  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     9.784 ms               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   9.877 ms ± 480.740 μs  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#            ▂▄▅▅▂▃█▅▅▆█
#   ▂▂▃▃▅▅▆▇▆██████████████▇█▅█▆▅▆▅▅▄▃▂▃▂▂▄▄▃▃▂▃▂▃▁▂▃▂▃▂▁▁▁▂▁▂▃ ▄
#   9.05 ms         Histogram: frequency by time        11.6 ms <
#
#  Memory estimate: 0 bytes, allocs estimate: 0.

# %% [markdown]
# Looking at the results above, it seems we're a bit under 10 ms for our simple matmul. Let's compare it with the equivalent from the standard library.

# %%
using LinearAlgebra
b_mul = @benchmark mul!(C,A,B)
# Out:
# BenchmarkTools.Trial: 10000 samples with 1 evaluation.
#  Range (min … max):  334.800 μs …   3.567 ms  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     470.400 μs               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   490.909 μs ± 111.051 μs  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#           ▁▄▅▅▆█▅▆▅▄▃▂▁
#   ▁▂▂▃▃▅▆▇██████████████▇▇▆▆▅▄▄▄▄▃▃▂▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁ ▃
#   335 μs           Histogram: frequency by time          851 μs <
#
#  Memory estimate: 0 bytes, allocs estimate: 0.

# %%
median(b_simple).time/median(b_mul).time
# Out:
# 20.799957482993197

# %% [markdown]
# That's quite the difference, as the standard library is about 20 times faster.

# %% [markdown]
# There are a couple of simple things we can do to improve on our implementation. First, we can change the order of the loops. Julia stores its arrays in Row Major Order, so we'll get better performance if we access the array elements column by column.

# %%
function better_mul!(C,A,B)
    m,n = size(C)
    l = size(A,2)
    for j in 1:n, k in 1:l, i in 1:m
        C[i,j] += A[i,k]*B[k,j]
    end
end
# Out:
# better_mul! (generic function with 1 method)

# %%
b_better = @benchmark better_mul!(C,A,B)
# Out:
# BenchmarkTools.Trial: 2780 samples with 1 evaluation.
#  Range (min … max):  1.456 ms …   5.217 ms  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     1.735 ms               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   1.791 ms ± 233.572 μs  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#         ▃▄▆▇▆█▆▄▃▃▄▂▁ ▁
#   ▂▂▃▃▅▇███████████████▇▇▆▆▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▃▂▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂ ▄
#   1.46 ms         Histogram: frequency by time         2.6 ms <
#
#  Memory estimate: 0 bytes, allocs estimate: 0.

# %% [markdown]
# That shaved a bit of performance, but still far from `mul!`.
#
# The reason reordering the loops improved performance is that modern computer memory is optimized for accessing contiguous areas of memory, so when traversing a Julia matrix by row instead of by column, we are getting what is called "cache misses" where we are jumping between areas of memory that are far apart.

# %% [markdown]
# Another simple trick we can use is turning off bounds checking. When accessing a Julia array, the Julia runtime checks that the index we're trying to access is valid (i.e. within the bounds of the array).
#
# If we already know that the index is valid, we can use the macro `@inbounds` to tell the Julia runtime to skip checking it.

# %%
function inbounds_mul!(C,A,B)
    m,n = size(C)
    l = size(A,2)
    for j in 1:n, k in 1:l, i in 1:m
        @inbounds C[i,j] += A[i,k]*B[k,j]
    end
end
# Out:
# inbounds_mul! (generic function with 1 method)

# %%
b_inbounds = @benchmark inbounds_mul!(C,A,B)
# Out:
# BenchmarkTools.Trial: 3095 samples with 1 evaluation.
#  Range (min … max):  1.348 ms …   4.534 ms  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     1.552 ms               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   1.609 ms ± 265.945 μs  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#     ▁▆█▆▆▆▅▄▂▃▁
#   ▃▇███████████▇▇▆▅▅▄▄▄▃▃▃▃▂▃▂▂▂▂▂▂▂▁▂▂▂▁▂▁▂▁▂▂▁▂▁▁▂▂▂▂▂▂▂▂▁▂ ▃
#   1.35 ms         Histogram: frequency by time        2.82 ms <
#
#  Memory estimate: 0 bytes, allocs estimate: 0.

# %% [markdown]
# As we can see, just adding a single macro call improved performance by 10. Not bad! But we can still do better.

# %% [markdown]
# The next thing to try is using the basic multithreading support from the standard library.

# %%
Threads.nthreads()
# Out:
# 1

# %% [markdown]
# Unfortunately, I can't get Jupyter notebooks to use multiple threads, so we'll have to do that part in the REPL. Just copy the next two cells in a Julia REPL (You'll have to open a REPL with `julia --threads=4` to start julia with multiple threads available).

# %%
function threaded_mul!(C,A,B)
    m,n = size(C)
    l = size(A,2)
    Threads.@threads for j in 1:n # NB. We can only apply this to the outer loop
        for k in 1:l, i in 1:m
          @inbounds C[i,j] += A[i,k]*B[k,j]
        end
    end
end
# Out:
# threaded_mul! (generic function with 1 method)

# %%
n = 256; A = rand(n,n); B = rand(n,n); C = rand(n,n)
using BenchmarkTools
b_threaded = @benchmark threaded_mul!(C,A,B)
# Out:
# BenchmarkTools.Trial: 2778 samples with 1 evaluation.
#  Range (min … max):  1.481 ms …   6.424 ms  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     1.746 ms               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   1.793 ms ± 227.034 μs  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#         ▃▅▄▅▆█▆▇▆▃▄▄▁▂▁▂ ▁
#   ▂▂▃▅▇▇████████████████▇██▇▆▆▆▆▅▅▄▄▄▄▄▄▃▃▃▃▃▂▃▃▂▂▁▂▂▁▁▂▂▂▂▁▂ ▄
#   1.48 ms         Histogram: frequency by time        2.49 ms <
#
#  Memory estimate: 720 bytes, allocs estimate: 6.

# %% [markdown]
# In the above, we get no speedup because this Jupyter Notebook only gets a single thread. When I run it in the REPL with 4 threads, I'm getting a median of 612 µs (slightly faster than `mul!`), but this does incur costs as we need to allocate memory for the `@threads` macro.

# %% [markdown]
# To finish this notebook, we'll use the `LoopVectorization` package, which export a magic macro called `@turbo` which performs a bunch of optimization on a loop, including using SIMD instructions when it can.

# %%
using LoopVectorization

# %%
function turbo_mul!(C,A,B)
    m,n = size(C)
    l = size(A,2)
    @turbo for j in 1:n # NB. We can only apply this to the outer loop
        for k in 1:l, i in 1:m
            @inbounds C[i,j] += A[i,k]*B[k,j]
        end
    end
end
# Out:
# turbo_mul! (generic function with 1 method)

# %%
b_turbo = @benchmark turbo_mul!(C,A,B)
# Out:
# BenchmarkTools.Trial: 3601 samples with 1 evaluation.
#  Range (min … max):  1.146 ms …   5.051 ms  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     1.335 ms               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   1.378 ms ± 192.370 μs  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#      ▂▃▅▆█▆▅▅▆▄▃▁▂▁
#   ▂▂▆███████████████▇█▆▅▅▅▄▅▃▃▃▄▃▂▃▃▃▃▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▂ ▄
#   1.15 ms         Histogram: frequency by time        2.11 ms <
#
#  Memory estimate: 0 bytes, allocs estimate: 0.

# %% [markdown]
# And *voilà*! We actually managed to be a little faster than `mul!` in this case.
# All it took was a single macro call.
#
# (NB. Keep in mind we're only looking at matrices of size 256, and our implementations don't check all the things they should to be correct).

# %% [markdown]
# Let's wrap up by comparing all our results on a plot. Aside from printing a pretty histogram, `@benchmark` actually returns the data from all its samples in an object, so we can access them.

# %%
using StatsPlots

boxplot(b_mul.times, label="mul!",
    yscale = :log10,
    ylabel = "Running time [ns]",
    title = "Matrix Multiplication Benchmark"
)
boxplot!(b_simple.times, label="simple_mul!")
boxplot!(b_better.times, label="better_mul!")
boxplot!(b_inbounds.times, label="inbounds_mul!")
boxplot!(b_threaded.times, label="threaded_mul!")
boxplot!(b_turbo.times, label="turbo_mul!")
